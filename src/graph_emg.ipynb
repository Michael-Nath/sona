# %% [markdown]
# In this notebook, you will find code for graphing the EMG data recorded from the Cyton BCI

# %%
import sys
from analysis.utils.pull_brain_data import get_brain_data_having_key
from analysis.utils.plotting_tools import graph_raw_cyton_data

# %%
# let's first get the cleaned cyton_data
clean_csv_key = "july-17-cleaned-shubh-data.csv"
cleaned_cyton_data = get_brain_data_having_key(clean_csv_key)

# %%
# let's plot the cleaned data
# print(cleaned_cyton_data.iloc[:,0])
graph_raw_cyton_data(cleaned_cyton_data)
